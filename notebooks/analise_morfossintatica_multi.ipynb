# %%
import sys
sys.path.insert(0, "..")

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords') 
nltk.download('perluni') 
nltk.download('nonbreaking_prefixes')

from corpus_processor import CorpusProcessor
from text_stats import TextStats
from pprint import pprint
from typing import List
# Out:
# [nltk_data] Downloading package punkt to /home/matheus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading perluni: Package 'perluni' not found in
# [nltk_data]     index
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!

# %%
def display_stats(stats: TextStats) -> None:
    frequencies = stats.extract_frequencies()
    num_sentencas = stats.get_num_sentences()
    num_tokens = stats.get_num_tokens()
    num_tokens_unicos = stats.get_num_unique_tokens()

    top_10_tokens = frequencies[['Token', 'Freq']].head(10)
    down_10_tokens = frequencies[['Token', 'Freq']].tail(10)

    contagens = stats.count_by_pos_tag()

    subs_comuns = contagens['NOUN']
    subs_proprios = contagens['PROPN']
    num_verbos = contagens['VERB']
    num_preposicoes = contagens['ADP']

    print('-' * 10)
    print('\nESTATÍSTICAS:\n')
    print(f'Número de Sentenças: {num_sentencas}\n')
    print(f'Número de Tokens: {num_tokens}\n')
    print(f'Número de Tokens únicos: {num_tokens_unicos}\n')
    print(f'Top 10 Tokens')
    pprint(top_10_tokens)
    print()
    print(f'Down 10 Tokens')
    pprint(down_10_tokens)
    print()
    print(f"Num. substantivos comuns: {subs_comuns}",)
    print(f"Num. substantivos próprios: {subs_proprios}")
    print(f"Total: {subs_comuns + subs_proprios}\n",)
    print(f"Número de Verbos: {num_verbos}\n")
    print(f"Número de Preposicoes: {num_preposicoes}\n")

def display_agg_stats(stats_list: List[TextStats]) -> None:
    num_tokens, num_tokens_unicos, num_sentencas = 0, 0, 0
    num_docs = len(stats_list)
    for stats in stats_list:
        num_tokens += stats.get_num_tokens()
        num_tokens_unicos += stats.get_num_unique_tokens()
        num_sentencas += stats.get_num_sentences()
    
    avg_num_tokens = float(num_tokens) / num_docs
    avg_num_tokens_unicos = float(num_tokens_unicos) / num_docs
    avg_num_sentencas = float(num_sentencas) / num_docs

    print('-' * 10)
    print('\nESTATÍSTICAS AGREGADAS:\n')
    print(f'Número Médio de Sentenças: {avg_num_sentencas}\n')
    print(f'Número Médio de Tokens: {avg_num_tokens}\n')
    print(f'Número Médio de Tokens únicos: {avg_num_tokens_unicos}\n')

# %%
processor = CorpusProcessor("../input/", "pt")

# %%
articles = processor.pdf_to_text_multiproc()
# Out:
#  93%|█████████▎| 126/136 [00:36<00:03,  2.83it/s]
# 100%|██████████| 109/109 [00:31<00:00,  3.47it/s]
# 100%|██████████| 136/136 [00:39<00:00,  3.45it/s]
# 100%|██████████| 151/151 [00:45<00:00,  3.29it/s]
# 100%|██████████| 131/131 [00:38<00:00,  3.43it/s]
# 100%|██████████| 125/125 [00:35<00:00,  3.47it/s]
# 100%|██████████| 171/171 [00:49<00:00,  3.45it/s]
# 100%|██████████| 235/235 [01:13<00:00,  3.19it/s]
# 100%|██████████| 144/144 [00:42<00:00,  3.36it/s]
# 100%|██████████| 144/144 [00:41<00:00,  3.50it/s]

# %%
articles.keys()
# Out:
# dict_keys(['30010-2546-24450-1-10-20240828.pdf', '17219-2102-13810-1-10-20210916.pdf', '21500-2102-17427-1-10-20220825.pdf', '17221-2102-13812-1-10-20210916.pdf', '17220-2102-13811-1-10-20210916.pdf', '26633-2174-22007-1-10-20231218.pdf', '30009-2546-24449-1-10-20240828.pdf', '30006-2546-24446-2-10-20240903.pdf', '21499-2102-17426-1-10-20220825.pdf', '29866-301-24307-1-10-20240810.pdf', '21498-2102-17425-1-10-20220825.pdf', '29824-157-24265-1-10-20240808.pdf', '31631-2606-25940-1-10-20241121.pdf', '30011-2546-24451-1-10-20240828.pdf', '29800-157-24241-1-10-20240808.pdf', '30007-2546-24447-1-10-20240828.pdf', '21496-2102-17423-1-10-20220825.pdf', '21494-2102-17421-1-10-20220825.pdf', '21495-2102-17422-1-10-20220825.pdf', '21493-2102-17420-1-10-20220825.pdf'])

# %%
all_stats = {}

for fname, content in articles.items():
    stats = TextStats(content)
    all_stats[fname] = stats

    print(fname)
    display_stats(stats)
# Out:
# 30010-2546-24450-1-10-20240828.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 127
#
# Número de Tokens: 3011
#
# Número de Tokens únicos: 942
#
# Top 10 Tokens
#          Token  Freq
# 0            ,   185
# 1            .   127
# 2     quântica    57
# 3         rede    52
# 4  simuladores    34
# 5            ✓    34
# 6    quânticos    24
# 7            ]    24
# 8            [    24
# 9    simulação    21
#
# Down 10 Tokens
#                Token  Freq
# 852           FAPESP     1
# 853            Paulo     1
# 854         Pesquisa     1
# 855         Fundação     1
# 856             CNPQ     1
# 857      Tecnológico     1
# 858       Científico     1
# 859  Desenvolvimento     1
# 860         Nacional     1
# 861         Conselho     1
#
# Num. substantivos comuns: 762
# Num. substantivos próprios: 232
# Total: 994
#
# Número de Verbos: 275
#
# Número de Preposicoes: 451
#
# 17219-2102-13810-1-10-20210916.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 135
#
# Número de Tokens: 2916
#
# Número de Tokens únicos: 905
#
# Top 10 Tokens
#            Token  Freq
# 0              ,   165
# 1              .   133
# 2              (    60
# 3              )    59
# 4     linguagens    30
# 5              [    26
# 6              ]    26
# 7              :    25
# 8              1    25
# 9  programac¸˜ao    25
#
# Down 10 Tokens
#             Token  Freq
# 833     tutoriais     1
# 834  instalac¸˜ao     1
# 835       compara     1
# 836        vis˜ao     1
# 837      presents     1
# 838          This     1
# 839          used     1
# 840            be     1
# 841        choose     1
# 842       sintaxe     1
#
# Num. substantivos comuns: 553
# Num. substantivos próprios: 493
# Total: 1046
#
# Número de Verbos: 245
#
# Número de Preposicoes: 363
#
# 21500-2102-17427-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 132
#
# Número de Tokens: 3795
#
# Número de Tokens únicos: 1120
#
# Top 10 Tokens
#   Token  Freq
# 0     ,   165
# 1     |   142
# 2     .   132
# 3     )    60
# 4     (    57
# 5     [    28
# 6     V    27
# 7     ]    27
# 8     2    26
# 9     1    23
#
# Down 10 Tokens
#                     Token  Freq
# 1008            modificar     1
# 1009                  vêm     1
# 1010                posse     1
# 1011                 EPCs     1
# 1012              REFORMA     1
# 1013    PTC/EEII-TEL/8017     1
# 1014         QuantumPrime     1
# 1015              Projeto     1
# 1016              Compete     1
# 1017  Internacionalização     1
#
# Num. substantivos comuns: 712
# Num. substantivos próprios: 569
# Total: 1281
#
# Número de Verbos: 324
#
# Número de Preposicoes: 502
#
# 17221-2102-13812-1-10-20210916.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 194
#
# Número de Tokens: 3664
#
# Número de Tokens únicos: 1183
#
# Top 10 Tokens
#        Token  Freq
# 0          ,   284
# 1          .   194
# 2  quˆantica    42
# 3          (    41
# 4          )    41
# 5          ]    31
# 6          [    31
# 7        and    30
# 8   Internet    28
# 9         ´e    27
#
# Down 10 Tokens
#            Token  Freq
# 1098       ahead     1
# 1099         362     1
# 1100        :303     1
# 1101        dis-     1
# 1102        cute     1
# 1103       Monga     1
# 1104          I.     1
# 1105      Newell     1
# 1106  Nomerotski     1
# 1107         Yoo     1
#
# Num. substantivos comuns: 648
# Num. substantivos próprios: 623
# Total: 1271
#
# Número de Verbos: 317
#
# Número de Preposicoes: 412
#
# 17220-2102-13811-1-10-20210916.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 151
#
# Número de Tokens: 3012
#
# Número de Tokens únicos: 1042
#
# Top 10 Tokens
#            Token  Freq
# 0              ,   293
# 1              .   150
# 2              )    26
# 3              (    26
# 4       Internet    23
# 5  publicac¸˜oes    21
# 6      Quˆantica    20
# 7              [    19
# 8              ]    19
# 9   Universidade    18
#
# Down 10 Tokens
#                Token  Freq
# 961            P.-F.     1
# 962              Sun     1
# 963             Jing     1
# 964            X.-Y.     1
# 965              Luo     1
# 966               Ma     1
# 967        1140–1144     1
# 968       kilometers     1
# 969  Satellite-based     1
# 970              Dai     1
#
# Num. substantivos comuns: 501
# Num. substantivos próprios: 641
# Total: 1142
#
# Número de Verbos: 223
#
# Número de Preposicoes: 395
#
# 26633-2174-22007-1-10-20231218.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 87
#
# Número de Tokens: 1970
#
# Número de Tokens únicos: 763
#
# Top 10 Tokens
#           Token  Freq
# 0             ,   111
# 1             .    87
# 2           QKD    34
# 3             )    32
# 4             (    32
# 5          rede    18
# 6        chaves    16
# 7             1    14
# 8             %    12
# 9  criptografia    11
#
# Down 10 Tokens
#               Token  Freq
# 694  superposic¸˜ao     1
# 695        ambiente     1
# 696      acadˆemico     1
# 697    computac¸˜ao     1
# 698     desempenham     1
# 699         crucial     1
# 700    compreens˜ao     1
# 701     fundamentos     1
# 702         postula     1
# 703        padr˜oes     1
#
# Num. substantivos comuns: 362
# Num. substantivos próprios: 351
# Total: 713
#
# Número de Verbos: 174
#
# Número de Preposicoes: 287
#
# 30009-2546-24449-1-10-20240828.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 152
#
# Número de Tokens: 3141
#
# Número de Tokens únicos: 986
#
# Top 10 Tokens
#          Token  Freq
# 0            ,   210
# 1            .   152
# 2            (    44
# 3            )    43
# 4            ]    40
# 5            [    40
# 6     quântica    30
# 7         rede    27
# 8  polarização    19
# 9            |    17
#
# Down 10 Tokens
#          Token  Freq
# 893     Nature     1
# 894  Photonics     1
# 895         11     1
# 896    678–680     1
# 897      Faria     1
# 898        Von     1
# 899        der     1
# 900       Weid     1
# 901   Controle     1
# 902      total     1
#
# Num. substantivos comuns: 596
# Num. substantivos próprios: 477
# Total: 1073
#
# Número de Verbos: 233
#
# Número de Preposicoes: 428
#
# 30006-2546-24446-2-10-20240903.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 118
#
# Número de Tokens: 2890
#
# Número de Tokens únicos: 656
#
# Top 10 Tokens
#   Token  Freq
# 0     .   118
# 1     ,   117
# 2     [   113
# 3     ]   113
# 4     (   101
# 5     )    99
# 6     |    78
# 7     =    52
# 8     θ    48
# 9     1    33
#
# Down 10 Tokens
#           Token  Freq
# 573        cama     1
# 574     gráfico     1
# 575      função     1
# 576          γt     1
# 577           '     1
# 578         A.O     1
# 579    exploram     1
# 580      linear     1
# 581  Realizamos     1
# 582    possível     1
#
# Num. substantivos comuns: 455
# Num. substantivos próprios: 547
# Total: 1002
#
# Número de Verbos: 170
#
# Número de Preposicoes: 315
#
# 21499-2102-17426-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 140
#
# Número de Tokens: 2935
#
# Número de Tokens únicos: 1035
#
# Top 10 Tokens
#         Token  Freq
# 0           ,   274
# 1           .   140
# 2           (    34
# 3           )    34
# 4       redes    28
# 5  quˆanticas    27
# 6         and    27
# 7           ]    19
# 8           [    19
# 9  roteamento    19
#
# Down 10 Tokens
#      Token  Freq
# 956  J.-W.     1
# 957    Pan     1
# 958  J.-Y.     1
# 959  C.-Z.     1
# 960   Peng     1
# 961    Shu     1
# 962  C.-Y.     1
# 963  Y.-A.     1
# 964   Chen     1
# 965  N.-L.     1
#
# Num. substantivos comuns: 517
# Num. substantivos próprios: 518
# Total: 1035
#
# Número de Verbos: 241
#
# Número de Preposicoes: 318
#
# 29866-301-24307-1-10-20240810.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 147
#
# Número de Tokens: 3583
#
# Número de Tokens únicos: 1036
#
# Top 10 Tokens
#    Token  Freq
# 0      ,   186
# 1      .   147
# 2      (    38
# 3      )    38
# 4    QKD    36
# 5      1    26
# 6    Bob    24
# 7      [    23
# 8  Alice    23
# 9      ]    23
#
# Down 10 Tokens
#                Token  Freq
# 923           Amparo     1
# 924         Fundação     1
# 925             CNPq     1
# 926      Tecnológico     1
# 927       Científico     1
# 928  Desenvolvimento     1
# 929         Nacional     1
# 930         Conselho     1
# 931       financiado     1
# 932     parcialmente     1
#
# Num. substantivos comuns: 756
# Num. substantivos próprios: 415
# Total: 1171
#
# Número de Verbos: 306
#
# Número de Preposicoes: 532
#
# 21498-2102-17425-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 109
#
# Número de Tokens: 3235
#
# Número de Tokens únicos: 936
#
# Top 10 Tokens
#   Token  Freq
# 0     ,   206
# 1     .   109
# 2     ]    93
# 3     [    93
# 4     (    64
# 5     )    62
# 6     1    36
# 7     n    35
# 8     m    24
# 9     }    20
#
# Down 10 Tokens
#                                Token  Freq
# 841                          Digcore     1
# 842                            Ações     1
# 843  UIDB/50008/2020-UIDP/50008/2020     1
# 844                              820     1
# 845                           PTDCEI     1
# 846                      projetos/80     1
# 847                             8020     1
# 848                               A.     1
# 849                             Nuno     1
# 850                        Maur´ıcio     1
#
# Num. substantivos comuns: 571
# Num. substantivos próprios: 458
# Total: 1029
#
# Número de Verbos: 215
#
# Número de Preposicoes: 408
#
# 29824-157-24265-1-10-20240808.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 270
#
# Número de Tokens: 6306
#
# Número de Tokens únicos: 1333
#
# Top 10 Tokens
#     Token  Freq
# 0       ,   302
# 1       .   270
# 2       :   105
# 3       (    79
# 4       )    79
# 5       ]    59
# 6       [    59
# 7    rede    51
# 8     EPR    50
# 9  qubits    46
#
# Down 10 Tokens
#                  Token  Freq
# 1228        Científico     1
# 1229          Nacional     1
# 1230          Conselho     1
# 1231        financiado     1
# 1232      parcialmente     1
# 1233    Agradecimentos     1
# 1234           futuras     1
# 1235  sustentabilidade     1
# 1236          Pimentel     1
# 1237            Arthur     1
#
# Num. substantivos comuns: 1349
# Num. substantivos próprios: 745
# Total: 2094
#
# Número de Verbos: 479
#
# Número de Preposicoes: 883
#
# 31631-2606-25940-1-10-20241121.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 109
#
# Número de Tokens: 2370
#
# Número de Tokens únicos: 752
#
# Top 10 Tokens
#    Token  Freq
# 0      ,   121
# 1      .   109
# 2    QKD    41
# 3  redes    25
# 4     al    25
# 5     et    25
# 6   rede    21
# 7      (    20
# 8      )    20
# 9      [    19
#
# Down 10 Tokens
#               Token  Freq
# 663           medem     1
# 664        inerente     1
# 665      correlação     1
# 666           eleva     1
# 667         baseado     1
# 668       coincidem     1
# 669  correspondente     1
# 670             bit     1
# 671        adiciona     1
# 672      distâncias     1
#
# Num. substantivos comuns: 562
# Num. substantivos próprios: 259
# Total: 821
#
# Número de Verbos: 189
#
# Número de Preposicoes: 402
#
# 30011-2546-24451-1-10-20240828.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 149
#
# Número de Tokens: 4340
#
# Número de Tokens únicos: 840
#
# Top 10 Tokens
#          Token  Freq
# 0            [   189
# 1            ,   187
# 2            ]   183
# 3            .   152
# 4            )    83
# 5            (    82
# 6            |    68
# 7            v    64
# 8            V    38
# 9  codificação    37
#
# Down 10 Tokens
#           Token  Freq
# 743   Dividimos     1
# 744        fixo     1
# 745      possui     1
# 746     levados     1
# 747    latência     1
# 748     efeitos     1
# 749      melhor     1
# 750  investigar     1
# 751    objetivo     1
# 752  simulações     1
#
# Num. substantivos comuns: 849
# Num. substantivos próprios: 613
# Total: 1462
#
# Número de Verbos: 318
#
# Número de Preposicoes: 576
#
# 29800-157-24241-1-10-20240808.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 236
#
# Número de Tokens: 6250
#
# Número de Tokens únicos: 1579
#
# Top 10 Tokens
#      Token  Freq
# 0        ,   289
# 1        .   236
# 2        [   102
# 3        ]   102
# 4        )    89
# 5        (    86
# 6  ataques    42
# 7    dados    41
# 8     qIDS    32
# 9      QML    31
#
# Down 10 Tokens
#           Token  Freq
# 1464      ativa     1
# 1465       área     1
# 1466      sendo     1
# 1467   continua     1
# 1468  ambientes     1
# 1469    prática     1
# 1470  superados     1
# 1471     FAPESP     1
# 1472      Paulo     1
# 1473     Estado     1
#
# Num. substantivos comuns: 1219
# Num. substantivos próprios: 870
# Total: 2089
#
# Número de Verbos: 478
#
# Número de Preposicoes: 896
#
# 30007-2546-24447-1-10-20240828.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 125
#
# Número de Tokens: 2925
#
# Número de Tokens únicos: 969
#
# Top 10 Tokens
#              Token  Freq
# 0                ,   197
# 1                .   125
# 2                ]    28
# 3                [    28
# 4                :    27
# 5        circuitos    25
# 6  particionamento    23
# 7        quânticos    22
# 8                %    22
# 9                ;    22
#
# Down 10 Tokens
#              Token  Freq
# 886        results     1
# 887           well     1
# 888       presents     1
# 889          paper     1
# 890           This     1
# 891     partitions     1
# 892          costs     1
# 893  communication     1
# 894     estratégia     1
# 895   hypergraphic     1
#
# Num. substantivos comuns: 666
# Num. substantivos próprios: 412
# Total: 1078
#
# Número de Verbos: 188
#
# Número de Preposicoes: 427
#
# 21496-2102-17423-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 123
#
# Número de Tokens: 2813
#
# Número de Tokens únicos: 799
#
# Top 10 Tokens
#        Token  Freq
# 0          .   122
# 1          ,   117
# 2          )    40
# 3          (    40
# 4    colisão    36
# 5  protocolo    28
# 6          [    28
# 7          ]    28
# 8          1    25
# 9    mascote    22
#
# Down 10 Tokens
#               Token  Freq
# 704        comparar     1
# 705       poderosos     1
# 706        original     1
# 707        primeiro     1
# 708      discutimos     1
# 709           seção     1
# 710            lado     1
# 711    Aproveitamos     1
# 712    aproveitamos     1
# 713  computacionais     1
#
# Num. substantivos comuns: 595
# Num. substantivos próprios: 322
# Total: 917
#
# Número de Verbos: 249
#
# Número de Preposicoes: 405
#
# 21494-2102-17421-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 142
#
# Número de Tokens: 3309
#
# Número de Tokens únicos: 748
#
# Top 10 Tokens
#      Token  Freq
# 0        ,   180
# 1        .   142
# 2        [   100
# 3        ]    96
# 4        (    62
# 5        )    62
# 6        =    47
# 7   M-APSK    45
# 8  excesso    26
# 9        1    24
#
# Down 10 Tokens
#                     Token  Freq
# 669              European     1
# 670              Regional     1
# 671           Development     1
# 672                  Fund     1
# 673                 FEDER     1
# 674       Competitiveness     1
# 675  Internationalization     1
# 676           Operational     1
# 677             Programme     1
# 678               COMPETE     1
#
# Num. substantivos comuns: 580
# Num. substantivos próprios: 490
# Total: 1070
#
# Número de Verbos: 171
#
# Número de Preposicoes: 469
#
# 21495-2102-17422-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 249
#
# Número de Tokens: 5508
#
# Número de Tokens únicos: 1101
#
# Top 10 Tokens
#    Token  Freq
# 0      ,   395
# 1      .   248
# 2      (    75
# 3      )    73
# 4    the    55
# 5    QKD    42
# 6      [    38
# 7      ]    38
# 8  sinal    37
# 9     of    36
#
# Down 10 Tokens
#              Token  Freq
# 1019  Comunicações     1
# 1020           1-3     1
# 1021         gerar     1
# 1022           GHz     1
# 1023           117     1
# 1024       simples     1
# 1025             9     1
# 1026        Nelson     1
# 1027  Departamento     1
# 1028    Eletrônica     1
#
# Num. substantivos comuns: 960
# Num. substantivos próprios: 922
# Total: 1882
#
# Número de Verbos: 432
#
# Número de Preposicoes: 734
#
# 21493-2102-17420-1-10-20220825.pdf
# ----------
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 144
#
# Número de Tokens: 3608
#
# Número de Tokens únicos: 949
#
# Top 10 Tokens
#         Token  Freq
# 0           ,   227
# 1           .   144
# 2           [    97
# 3           ]    96
# 4           (    52
# 5           )    52
# 6           2    45
# 7       ruído    38
# 8  estimativa    28
# 9           |    27
#
# Down 10 Tokens
#            Token  Freq
# 861    executado     1
# 862       2,4576     1
# 863         gs/s     1
# 864  alimentados     1
# 865      estágio     1
# 866      relógio     1
# 867       etapas     1
# 868     inserido     1
# 869            F     1
# 870    conversor     1
#
# Num. substantivos comuns: 696
# Num. substantivos próprios: 497
# Total: 1193
#
# Número de Verbos: 247
#
# Número de Preposicoes: 555

# %%
display_agg_stats(list(all_stats.values()))
# Out:
# ----------
#
# ESTATÍSTICAS AGREGADAS:
#
# Número Médio de Sentenças: 151.95
#
# Número Médio de Tokens: 3579.05
#
# Número Médio de Tokens únicos: 983.7
