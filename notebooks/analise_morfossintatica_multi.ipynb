# %%
import sys
sys.path.insert(0, "..")

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords') 
nltk.download('perluni') 
nltk.download('nonbreaking_prefixes')

from corpus_processor import CorpusProcessor
from text_stats import TextStats
from pprint import pprint
from typing import List
# Out:
# [nltk_data] Downloading package punkt to /home/matheus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading perluni: Package 'perluni' not found in
# [nltk_data]     index
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!

# %%
def display_stats(stats: TextStats, title=None) -> None:
    frequencies = stats.extract_frequencies()
    num_sentencas = stats.get_num_sentences()
    num_tokens = stats.get_num_tokens()
    num_tokens_unicos = stats.get_num_unique_tokens()

    top_10_tokens = frequencies[['Token', 'Freq']].head(10)
    down_10_tokens = frequencies[['Token', 'Freq']].tail(10)

    contagens = stats.count_by_pos_tag()

    subs_comuns = contagens['NOUN']
    subs_proprios = contagens['PROPN']
    num_verbos = contagens['VERB']
    num_preposicoes = contagens['ADP']

    print('-' * 10)
    if title:
        print(f"Texto: {title}")
    print('\nESTATÍSTICAS:\n')
    print(f'Número de Sentenças: {num_sentencas}\n')
    print(f'Número de Tokens: {num_tokens}\n')
    print(f'Número de Tokens únicos: {num_tokens_unicos}\n')
    print(f'Top 10 Tokens')
    pprint(top_10_tokens)
    print()
    print(f'Down 10 Tokens')
    pprint(down_10_tokens)
    print()
    print(f"Num. substantivos comuns: {subs_comuns}",)
    print(f"Num. substantivos próprios: {subs_proprios}")
    print(f"Total: {subs_comuns + subs_proprios}\n",)
    print(f"Número de Verbos: {num_verbos}\n")
    print(f"Número de Preposicoes: {num_preposicoes}\n")

def display_agg_stats(stats_list: List[TextStats]) -> None:
    num_tokens, num_tokens_unicos, num_sentencas = 0, 0, 0
    num_docs = len(stats_list)
    for stats in stats_list:
        num_tokens += stats.get_num_tokens()
        num_tokens_unicos += stats.get_num_unique_tokens()
        num_sentencas += stats.get_num_sentences()
    
    avg_num_tokens = float(num_tokens) / num_docs
    avg_num_tokens_unicos = float(num_tokens_unicos) / num_docs
    avg_num_sentencas = float(num_sentencas) / num_docs

    print('-' * 10)
    print('\nESTATÍSTICAS AGREGADAS:\n')
    print(f'Número Médio de Sentenças: {avg_num_sentencas}\n')
    print(f'Número Médio de Tokens: {avg_num_tokens}\n')
    print(f'Número Médio de Tokens únicos: {avg_num_tokens_unicos}\n')

# %%
processor = CorpusProcessor("../input/", "pt")

# %%
articles = processor.pdf_to_text_multiproc()
# Out:
# 100%|██████████| 94/94 [00:52<00:00,  1.80it/s]]
# 100%|██████████| 109/109 [00:56<00:00,  1.92it/s]
# 100%|██████████| 127/127 [01:11<00:00,  1.78it/s]
# 100%|██████████| 136/136 [01:11<00:00,  1.89it/s]
# 100%|██████████| 125/125 [01:07<00:00,  1.85it/s]
# 100%|██████████| 131/131 [01:08<00:00,  1.92it/s]
# 100%|██████████| 171/171 [01:31<00:00,  1.87it/s]
# 100%|██████████| 235/235 [02:05<00:00,  1.87it/s]
# 100%|██████████| 144/144 [01:10<00:00,  2.03it/s]
# 100%|██████████| 98/98 [00:54<00:00,  1.81it/s]

# %%
articles.keys()
# Out:
# dict_keys(['30010-2546-24450-1-10-20240828.pdf', '17219-2102-13810-1-10-20210916.pdf', '21500-2102-17427-1-10-20220825.pdf', '17221-2102-13812-1-10-20210916.pdf', '17220-2102-13811-1-10-20210916.pdf', '26633-2174-22007-1-10-20231218.pdf', '30009-2546-24449-1-10-20240828.pdf', '30006-2546-24446-2-10-20240903.pdf', '21499-2102-17426-1-10-20220825.pdf', '29866-301-24307-1-10-20240810.pdf', '21498-2102-17425-1-10-20220825.pdf', '29824-157-24265-1-10-20240808.pdf', '31631-2606-25940-1-10-20241121.pdf', '30011-2546-24451-1-10-20240828.pdf', '29800-157-24241-1-10-20240808.pdf', '30007-2546-24447-1-10-20240828.pdf', '21496-2102-17423-1-10-20220825.pdf', '21494-2102-17421-1-10-20220825.pdf', '21495-2102-17422-1-10-20220825.pdf', '21493-2102-17420-1-10-20220825.pdf'])

# %%
all_stats = {}

for fname, content in articles.items():
    stats = TextStats(content)
    all_stats[fname] = stats

    display_stats(stats, title=fname)
# Out:
# ----------
# Texto: 30010-2546-24450-1-10-20240828.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 127
#
# Número de Tokens: 3007
#
# Número de Tokens únicos: 942
#
# Top 10 Tokens
#          Token  Freq
# 0     quântica    57
# 1         rede    52
# 2  simuladores    34
# 3            ✓    34
# 4    quânticos    24
# 5    simulação    21
# 6    simulador    19
# 7        redes    18
# 8        disso    15
# 9         Além    15
#
# Down 10 Tokens
#                Token  Freq
# 844     2020/04031-1     1
# 845              sob     1
# 846           FAPESP     1
# 847            Paulo     1
# 848         Pesquisa     1
# 849         Fundação     1
# 850             CNPQ     1
# 851      Tecnológico     1
# 852       Científico     1
# 853  Desenvolvimento     1
#
# Num. substantivos comuns: 760
# Num. substantivos próprios: 237
# Total: 997
#
# Número de Verbos: 275
#
# Número de Preposicoes: 450
#
# ----------
# Texto: 17219-2102-13810-1-10-20210916.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 83
#
# Número de Tokens: 2457
#
# Número de Tokens únicos: 750
#
# Top 10 Tokens
#          Token  Freq
# 0   linguagens    30
# 1            1    25
# 2  programação    25
# 3    quânticas    22
# 4  bibliotecas    17
# 5    quânticos    16
# 6   algoritmos    16
# 7       qubits    15
# 8     pesquisa    13
# 9   desempenho    13
#
# Down 10 Tokens
#              Token  Freq
# 655      satisfaça     1
# 656           item     1
# 657      encontrar     1
# 658             dá     1
# 659  não-ordenados     1
# 660   |Grover|Dada     1
# 661           1992     1
# 662          Jozsa     1
# 663        Deutsch     1
# 664        período     1
#
# Num. substantivos comuns: 600
# Num. substantivos próprios: 249
# Total: 849
#
# Número de Verbos: 214
#
# Número de Preposicoes: 354
#
# ----------
# Texto: 21500-2102-17427-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 133
#
# Número de Tokens: 3808
#
# Número de Tokens únicos: 1121
#
# Top 10 Tokens
#        Token  Freq
# 0          V    27
# 1          2    26
# 2     tensão    23
# 3          1    23
# 4        EPC    21
# 5    valores    21
# 6          α    20
# 7        SOP    19
# 8  algoritmo    19
# 9       cada    16
#
# Down 10 Tokens
#                     Token  Freq
# 994     PTC/EEII-TEL/8017     1
# 995          QuantumPrime     1
# 996               Projeto     1
# 997               Compete     1
# 998   Internacionalização     1
# 999       Competitividade     1
# 1000          Operacional     1
# 1001             Programa     1
# 1002              através     1
# 1003               Feders     1
#
# Num. substantivos comuns: 711
# Num. substantivos próprios: 575
# Total: 1286
#
# Número de Verbos: 324
#
# Número de Preposicoes: 503
#
# ----------
# Texto: 17221-2102-13812-1-10-20210916.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 129
#
# Número de Tokens: 2961
#
# Número de Tokens únicos: 972
#
# Top 10 Tokens
#          Token  Freq
# 0     quântica    42
# 1     Internet    27
# 2        redes    24
# 3    quânticos    24
# 4         rede    21
# 5    quânticas    20
# 6           et    19
# 7           al    19
# 8  comunicação    16
# 9     quântico    15
#
# Down 10 Tokens
#            Token  Freq
# 860   beneficiar     1
# 861        nação     1
# 862  capacidades     1
# 863     aumentar     1
# 864    potencial     1
# 865       enorme     1
# 866       apesar     1
# 867      Federal     1
# 868   Rothenberg     1
# 869           R.     1
#
# Num. substantivos comuns: 647
# Num. substantivos próprios: 243
# Total: 890
#
# Número de Verbos: 286
#
# Número de Preposicoes: 398
#
# ----------
# Texto: 17220-2102-13811-1-10-20210916.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 96
#
# Número de Tokens: 2422
#
# Número de Tokens únicos: 884
#
# Top 10 Tokens
#           Token  Freq
# 0      Internet    23
# 1   publicações    21
# 2      Quântica    20
# 3  Universidade    18
# 4         dados    13
# 5       análise    13
# 6          2020    11
# 7  conhecimento    11
# 8    Tecnologia    10
# 9        Figura     9
#
# Down 10 Tokens
#              Token  Freq
# 785      sugere-se     1
# 786    complemento     1
# 787          rotas     1
# 788    tecnológico     1
# 789              T     1
# 790      Sociedade     1
# 791         poderá     1
# 792         afetar     1
# 793  significativa     1
# 794        sistema     1
#
# Num. substantivos comuns: 490
# Num. substantivos próprios: 340
# Total: 830
#
# Número de Verbos: 192
#
# Número de Preposicoes: 395
#
# ----------
# Texto: 26633-2174-22007-1-10-20231218.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 73
#
# Número de Tokens: 1828
#
# Número de Tokens únicos: 715
#
# Top 10 Tokens
#           Token  Freq
# 0           QKD    33
# 1          rede    18
# 2        chaves    16
# 3             1    14
# 4  criptografia    11
# 5          UFPA    11
# 6  autenticação     9
# 7      quântica     9
# 8         redes     8
# 9             2     8
#
# Down 10 Tokens
#           Token  Freq
# 629      viável     1
# 630  demonstram     1
# 631       Diego     1
# 632    Pimentel     1
# 633      Arthur     1
# 634     Tavares     1
# 635       David     1
# 636  Desempenho     1
# 637        Alto     1
# 638   Simulação     1
#
# Num. substantivos comuns: 377
# Num. substantivos próprios: 269
# Total: 646
#
# Número de Verbos: 155
#
# Número de Preposicoes: 282
#
# ----------
# Texto: 30009-2546-24449-1-10-20240828.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 94
#
# Número de Tokens: 2577
#
# Número de Tokens únicos: 836
#
# Top 10 Tokens
#          Token  Freq
# 0         rede    27
# 1     quântica    21
# 2  polarização    17
# 3          Rio    16
# 4        Alice    13
# 5            2    13
# 6            1    13
# 7          Bob    12
# 8         link    12
# 9        fibra    11
#
# Down 10 Tokens
#                Token  Freq
# 729  desenvolveremos     1
# 730              luz     1
# 731      estruturada     1
# 732         carregam     1
# 733           Khoury     1
# 734         Elétrica     1
# 735          alterar     1
# 736          nenhuma     1
# 737             fato     1
# 738      escritórios     1
#
# Num. substantivos comuns: 505
# Num. substantivos próprios: 321
# Total: 826
#
# Número de Verbos: 226
#
# Número de Preposicoes: 381
#
# ----------
# Texto: 30006-2546-24446-2-10-20240903.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 118
#
# Número de Tokens: 2888
#
# Número de Tokens únicos: 666
#
# Top 10 Tokens
#     Token  Freq
# 0       θ    48
# 1       1    33
# 2  estado    32
# 3       s    30
# 4       2    30
# 5       ⟩    22
# 6       C    20
# 7       0    20
# 8       r    19
# 9  canais    17
#
# Down 10 Tokens
#            Token  Freq
# 563     exploram     1
# 564       finais     1
# 565  Observações     1
# 566    previsões     1
# 567       acordo     1
# 568        perda     1
# 569   congelados     1
# 570      máximos     1
# 571        Então     1
# 572        Agora     1
#
# Num. substantivos comuns: 458
# Num. substantivos próprios: 552
# Total: 1010
#
# Número de Verbos: 167
#
# Número de Preposicoes: 318
#
# ----------
# Texto: 21499-2102-17426-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 95
#
# Número de Tokens: 2263
#
# Número de Tokens únicos: 820
#
# Top 10 Tokens
#             Token  Freq
# 0           redes    28
# 1       quânticas    27
# 2      roteamento    19
# 3            rede    19
# 4        quântica    17
# 5       quânticos    16
# 6              et    14
# 7              al    14
# 8              nó    13
# 9  entrelaçamento    12
#
# Down 10 Tokens
#               Token  Freq
# 720      Planeja-se     1
# 721            rota     1
# 722      descoberta     1
# 723       assegurem     1
# 724       aprovamos     1
# 725      essenciais     1
# 726  interoperáveis     1
# 727     subsistemas     1
# 728      construção     1
# 729        críticos     1
#
# Num. substantivos comuns: 492
# Num. substantivos próprios: 198
# Total: 690
#
# Número de Verbos: 219
#
# Número de Preposicoes: 318
#
# ----------
# Texto: 29866-301-24307-1-10-20240810.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 147
#
# Número de Tokens: 3583
#
# Número de Tokens únicos: 1036
#
# Top 10 Tokens
#          Token  Freq
# 0          QKD    36
# 1            1    26
# 2          Bob    24
# 3        Alice    23
# 4           et    22
# 5           al    22
# 6        redes    20
# 7  requisições    19
# 8       chaves    19
# 9   aplicações    18
#
# Down 10 Tokens
#               Token  Freq
# 911    parcialmente     1
# 912  Agradecimentos     1
# 913         Federal     1
# 914    Universidade     1
# 915          Exatas     1
# 916        Ciências     1
# 917       Instituto     1
# 918         Antônio     1
# 919           Diego     1
# 920        Pimentel     1
#
# Num. substantivos comuns: 756
# Num. substantivos próprios: 415
# Total: 1171
#
# Número de Verbos: 306
#
# Número de Preposicoes: 532
#
# ----------
# Texto: 21498-2102-17425-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 109
#
# Número de Tokens: 3222
#
# Número de Tokens únicos: 945
#
# Top 10 Tokens
#            Token  Freq
# 0              1    36
# 1              n    35
# 2              m    24
# 3             al    19
# 4             et    19
# 5        entrada    18
# 6              0    16
# 7       extrator    15
# 8           hash    15
# 9  aleatoriedade    15
#
# Down 10 Tokens
#                Token  Freq
# 834        clássicas     1
# 835       estimativa     1
# 836            levar     1
# 837     consideração     1
# 838   especificidade     1
# 839           alguma     1
# 840        extraível     1
# 841  necessariamente     1
# 842           manter     1
# 843      introduzida     1
#
# Num. substantivos comuns: 565
# Num. substantivos próprios: 473
# Total: 1038
#
# Número de Verbos: 214
#
# Número de Preposicoes: 401
#
# ----------
# Texto: 29824-157-24265-1-10-20240808.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 270
#
# Número de Tokens: 6306
#
# Número de Tokens únicos: 1333
#
# Top 10 Tokens
#         Token  Freq
# 0        rede    51
# 1         EPR    50
# 2      qubits    46
# 3    ReqRoute    43
# 4  fidelidade    41
# 5          al    39
# 6          et    39
# 7       pares    37
# 8           1    36
# 9  roteamento    35
#
# Down 10 Tokens
#                  Token  Freq
# 1217          Pesquisa     1
# 1218             Paulo     1
# 1219            mantém     1
# 1220      contribuindo     1
# 1221  sustentabilidade     1
# 1222           futuras     1
# 1223    Agradecimentos     1
# 1224      parcialmente     1
# 1225        financiado     1
# 1226          Conselho     1
#
# Num. substantivos comuns: 1349
# Num. substantivos próprios: 745
# Total: 2094
#
# Número de Verbos: 479
#
# Número de Preposicoes: 883
#
# ----------
# Texto: 31631-2606-25940-1-10-20241121.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 109
#
# Número de Tokens: 2370
#
# Número de Tokens únicos: 752
#
# Top 10 Tokens
#          Token  Freq
# 0          QKD    41
# 1        redes    25
# 2           al    25
# 3           et    25
# 4         rede    21
# 5          SDN    17
# 6       chaves    14
# 7     recursos    14
# 8    segurança    11
# 9  arquitetura    11
#
# Down 10 Tokens
#             Token  Freq
# 655        FAPESP     1
# 656  2020/04031-1     1
# 657  2021/00199-8     1
# 658           CPE     1
# 659     SMARTNESS     1
# 660  2023/00673-7     1
# 661       futuros     1
# 662  recomenda-se     1
# 663      expansão     1
# 664         novos     1
#
# Num. substantivos comuns: 562
# Num. substantivos próprios: 259
# Total: 821
#
# Número de Verbos: 189
#
# Número de Preposicoes: 402
#
# ----------
# Texto: 30011-2546-24451-1-10-20240828.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 149
#
# Número de Tokens: 4334
#
# Número de Tokens únicos: 844
#
# Top 10 Tokens
#          Token  Freq
# 0            v    64
# 1            V    38
# 2  codificação    37
# 3         rede    35
# 4            1    33
# 5       qubits    32
# 6     quântica    28
# 7           vu    26
# 8            c    26
# 9       estado    24
#
# Down 10 Tokens
#              Token  Freq
# 730          -node     1
# 731    seqüenciais     1
# 732     permitidas     1
# 733      Conclusão     1
# 734              i     1
# 735             ii     1
# 736          casos     1
# 737  especificamos     1
# 738    Distributed     1
# 739   consideração     1
#
# Num. substantivos comuns: 846
# Num. substantivos próprios: 619
# Total: 1465
#
# Número de Verbos: 317
#
# Número de Preposicoes: 570
#
# ----------
# Texto: 29800-157-24241-1-10-20240808.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 236
#
# Número de Tokens: 6250
#
# Número de Tokens únicos: 1579
#
# Top 10 Tokens
#       Token  Freq
# 0   ataques    42
# 1     dados    41
# 2      qIDS    32
# 3         1    31
# 4       QML    31
# 5  quântico    30
# 6  quântica    29
# 7         2    29
# 8       VQC    23
# 9      QSVM    23
#
# Down 10 Tokens
#             Token  Freq
# 1451     |Col1||0     1
# 1452         meas     1
# 1453       grupos     1
# 1454       Etapas     1
# 1455      próximo     1
# 1456     atribuir     1
# 1457   utiliza-se     1
# 1458   determinar     1
# 1459  entrelaçado     1
# 1460       tarefa     1
#
# Num. substantivos comuns: 1219
# Num. substantivos próprios: 870
# Total: 2089
#
# Número de Verbos: 478
#
# Número de Preposicoes: 896
#
# ----------
# Texto: 30007-2546-24447-1-10-20240828.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 125
#
# Número de Tokens: 2925
#
# Número de Tokens únicos: 969
#
# Top 10 Tokens
#              Token  Freq
# 0        circuitos    25
# 1  particionamento    23
# 2        quânticos    22
# 3          quantum    17
# 4         circuito    16
# 5          Quantum    15
# 6           qubits    15
# 7        partições    12
# 8      comunicação    12
# 9               p.    11
#
# Down 10 Tokens
#          Token  Freq
# 874     Samuel     1
# 875         JR     1
# 876   LOMONACO     1
# 877     Anocha     1
# 878    585-591     1
# 879         44     1
# 880        ACM     1
# 881  Algorithm     1
# 882    Min-Cut     1
# 883     Simple     1
#
# Num. substantivos comuns: 666
# Num. substantivos próprios: 412
# Total: 1078
#
# Número de Verbos: 188
#
# Número de Preposicoes: 427
#
# ----------
# Texto: 21496-2102-17423-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 123
#
# Número de Tokens: 2813
#
# Número de Tokens únicos: 799
#
# Top 10 Tokens
#        Token  Freq
# 0    colisão    36
# 1  protocolo    28
# 2          1    25
# 3    mascote    22
# 4     partes    21
# 5          i    19
# 6          0    16
# 7       QSMC    15
# 8          x    13
# 9        uso    13
#
# Down 10 Tokens
#                Token  Freq
# 689          pessoas     1
# 690             vida     1
# 691     conveniência     1
# 692           enorme     1
# 693          trazido     1
# 694  Competitividade     1
# 695      Operacional     1
# 696         Programa     1
# 697            Feder     1
# 698         Regional     1
#
# Num. substantivos comuns: 595
# Num. substantivos próprios: 322
# Total: 917
#
# Número de Verbos: 249
#
# Número de Preposicoes: 405
#
# ----------
# Texto: 21494-2102-17421-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 143
#
# Número de Tokens: 3388
#
# Número de Tokens únicos: 750
#
# Top 10 Tokens
#           Token  Freq
# 0        M-APSK    44
# 1             1    28
# 2       excesso    26
# 3            al    22
# 4            et    22
# 5        Aveiro    21
# 6       regular    21
# 7             0    21
# 8  constelações    21
# 9             p    20
#
# Down 10 Tokens
#             Token  Freq
# 654          pior     1
# 655    conclusões     1
# 656     Modulação     1
# 657      quântico     1
# 658  compartilham     1
# 659     limitando     1
# 660            βi     1
# 661            ba     1
# 662      alocados     1
# 663        buraco     1
#
# Num. substantivos comuns: 582
# Num. substantivos próprios: 500
# Total: 1082
#
# Número de Verbos: 173
#
# Número de Preposicoes: 475
#
# ----------
# Texto: 21495-2102-17422-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 249
#
# Número de Tokens: 5508
#
# Número de Tokens únicos: 1101
#
# Top 10 Tokens
#            Token  Freq
# 0            the    55
# 1            QKD    42
# 2          sinal    37
# 3             of    36
# 4    polarização    36
# 5       receptor    28
# 6        sistema    28
# 7  sincronização    25
# 8            EPC    24
# 9    transmissor    23
#
# Down 10 Tokens
#              Token  Freq
# 1007      branches     1
# 1008          both     1
# 1009     principle     1
# 1010     operation     1
# 1011           ACH     1
# 1012      operação     1
# 1013      Ferreira     1
# 1014          N.J.     1
# 1015           1-3     1
# 1016  Comunicações     1
#
# Num. substantivos comuns: 960
# Num. substantivos próprios: 922
# Total: 1882
#
# Número de Verbos: 432
#
# Número de Preposicoes: 734
#
# ----------
# Texto: 21493-2102-17420-1-10-20220825.pdf
#
# ESTATÍSTICAS:
#
# Número de Sentenças: 97
#
# Número de Tokens: 3146
#
# Número de Tokens únicos: 844
#
# Top 10 Tokens
#                        Token  Freq
# 0                          2    45
# 1                      ruído    38
# 2                 estimativa    28
# 3                       tiro    22
# 4                          1    20
# 5                          ˜    18
# 6                         al    17
# 7                          �    17
# 8                         et    17
# 9  |||||||||||||||||||||||||    16
#
# Down 10 Tokens
#                                Token  Freq
# 740                            Feder     1
# 741                          Impacto     1
# 742                             anos     1
# 743                 Subsh/BD/BD/1820     1
# 744                             2020     1
# 745                    SFRH/BD/BD/BD     1
# 746                  UIDP/50025/2020     1
# 747  UIDB/50008/2020-UIDP/50008/2020     1
# 748                          avaliar     1
# 749                     Apresentamos     1
#
# Num. substantivos comuns: 638
# Num. substantivos próprios: 400
# Total: 1038
#
# Número de Verbos: 239
#
# Número de Preposicoes: 516

# %%
display_agg_stats(list(all_stats.values()))
# Out:
# ----------
#
# ESTATÍSTICAS AGREGADAS:
#
# Número Médio de Sentenças: 135.25
#
# Número Médio de Tokens: 3402.8
#
# Número Médio de Tokens únicos: 932.9
